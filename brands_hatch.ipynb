# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

# IPython magic to create plots within cells
# %matplotlib inline 

# plot style
matplotlib.style.use('ggplot')

# %%
df = pd.read_csv('20171230_163321_bh_win.csv')

# %%
df2 = df

# %%
sns.pairplot(x_vars=["track"], y_vars=["speed"], data=df2, \
             hue="lap", aspect=2, size=5, palette='copper')
sns.plt.title('Brands Hatch Speed Analysis [By Lap] (Dec 2017)')
sns.plt.xlim(-50,4000)
# Out:
# (-50, 4000)

# %%
sns.pairplot(x_vars=["track"], y_vars=["speed"], data=df2, \
             hue="sector", aspect=2, size=5, palette='brg')
sns.plt.title('Brands Hatch Speed Analysis [By Sector] (Dec 2017)')
sns.plt.xlim(-50,4000)
# Out:
# (-50, 4000)

# %%
#sns.pairplot(data=df2[['rft','lft','lrt','rrt']])
#sns.pairplot(data=df2[['rfp','lfp','lrp','rrp']])

# %%
sns.boxplot(x='lap', y='speed', data=df2, palette='Set1')
sns.plt.title('Speed by Lap')

# %%
sns.boxplot(x='lap', y='speed', hue='sector', data=df2, palette='RdYlGn')
sns.plt.title('Speed by Lap/Sector')

# %%
## comparing some tire temp histograms 

#df.lft.hist(bins=25, color='darkblue')
#df.rft.hist(bins=25, color='lightblue')
df.lrt.hist(bins=25, color='darkgreen')
df.rrt.hist(bins=25, color='lightgreen')

# %%
df.lfp.hist(color='darkblue')
df.rfp.hist(color='lightblue')
df.lrp.hist(color='darkgreen')
df.rrp.hist(color='lightgreen')

# %%
#sns.kdeplot(df.y, df.x)
# 
# no idea what this is telling me yet between RF and LF temps
sns.kdeplot(df2.rft, df2.lft)

# %%
# more tire temp histograms

sns.distplot(df.rft, label='RF')
sns.distplot(df.lft, label='LF')
sns.plt.title('Left Front / Right Front Tire Temps')
sns.plt.legend()

# %%
sns.distplot(df.rft, label='RR', color='g')
sns.distplot(df.lft, label='LR' ,color='purple')
sns.plt.title('Right Rear / Left Rear Tire Temps')
sns.plt.legend()

# %%
# no idea how this chart helps ??
sns.jointplot(data=df2, x='lft', y='rft', color='g')

# %%
#  boxplot of Tire Temp per lap
# would like to get subplots per tire ??

sns.boxplot(x='lap', y='rft', data=df2, palette='Set1')
#sns.boxplot(x='lap', y='lft', data=df2, palette='copper')

sns.plt.title('RF Temp by Lap')

# %%
# tire temps for whole race  (almost 3500+ datapoints)

df2 = df
df2.set_index(df2.time)
df2.rft.plot(color='r', figsize=(10,6))
df2.lft.plot(color='g')
df2.rrt.plot(color='b')
df2.lrt.plot(color='y')
